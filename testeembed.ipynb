# %% [markdown]
# <a href="https://colab.research.google.com/github/ciceroduarte01/alura-ai/blob/main/testeembed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
#Importações e configurações iniciais
import numpy as np
import pandas as pd
import google.generativeai as genai

from google.colab import userdata
api_key = userdata.get('SECRET_KEY')
genai.configure(api_key = api_key)

# %%
for m in genai.list_models():
  if 'embedContent' in m.supported_generation_methods:
    print(m.name)

# %%
text = "Hello Word"
result =genai.embed_content(model="models/embedding-001", content=text)

#imprime apenas uma parte do embedding para manipular a saida

print(result['embedding'])
# Out:
# [0.04018242, -0.03704972, -0.04325986, -0.010896344, -0.00045492154, -0.021710863, 0.017026773, -0.0060086907, 0.029470207, -0.00047571954, 0.067521736, 0.046682805, -0.016875202, -0.06420341, -0.014988153, 0.016700136, 0.013260319, 0.0020212203, -0.021483913, -0.016418295, 0.016205719, 0.008860349, 0.00821412, -0.021634547, 0.020011071, 0.032622024, 0.001961826, -0.0671871, -0.03296656, 0.03389074, -0.047321968, 0.033349913, -0.068065934, -0.0011030292, 0.0056602247, -0.059404694, 0.026544088, 0.008836732, -3.7461105e-05, 0.021760495, 0.00092877744, -0.05109598, -0.01530746, -0.020785188, 0.038632866, 0.007407202, 0.021970103, 0.008346473, 0.008478836, -0.07711028, 0.07502881, 0.024115777, 0.019751592, -0.03510221, 0.000499711, -0.025276685, 0.05884862, 0.025516532, -0.032585915, 0.0014367509, -0.01042026, 0.031577293, -0.044586312, 0.04162167, -0.045595214, 0.0073460937, -0.07357041, 0.053705107, -0.006620662, 0.027603928, -0.0018739053, -0.0063870144, 0.045253363, -0.012616805, -0
# ...

# %%
print(len(result['embedding']))
# Out:
# 3

# %%
result = genai.embed_content(
    model="models/embedding-001",
    content=[
             'what is the meaning of life?',
             'how much wood a woodchuck chuck?',
             'how does the brain work?'
             ]
    )
for embedding in result['embedding']:
      print(str(embedding)[:50], '... TRIMMED]')
# Out:
# [-0.0054580946, -0.041917764, -0.010266466, -0.027 ... TRIMMED]
# [-0.024399368, -0.028071309, -0.03230826, -0.06439 ... TRIMMED]
# [0.012573349, -0.039673198, -0.02109878, -0.010486 ... TRIMMED]

# %%
# Exemplo de embedding
title = "The next generation of AI for developers and Google Workspace"
sample_text = ("Titulo: A Próxima geração de IA para desenvolvedores e Google Workspace"
    "\n"
    "Artigo Completo:\n"
    "\n"
    "Gemini API & Google AI Studio: Uma maneira acessível de explorar e criar protótipos com aplicaçãoes de IA generativa")

embeddings = genai.embed_content(model="models/embedding-001",
                                content=sample_text,
                                title=title,
                                task_type="RETRIEVAL_DOCUMENT")
print(embeddings)
# Out:
# {'embedding': [0.049011756, -0.046379436, -0.013973724, 0.007478837, 0.06920715, -0.00035607736, -0.024966469, -0.009875013, 0.05714414, 0.070800856, 0.004985617, 0.010846652, -0.050071865, -0.017067704, 0.012735854, -0.030778516, 0.032901622, 0.005906509, -0.045028888, 0.012150331, 0.019377433, -0.0056724558, -0.019369103, -0.072722316, -0.02438389, 0.0076764124, 0.020724526, -0.033164468, -0.029124895, 0.03659214, -0.05275092, 0.035925906, -0.042571474, 0.006045258, -0.029746545, -0.05389557, -0.024352832, -0.0457723, 0.0018361916, 0.0058092778, -0.002294046, -0.090537384, -0.0011798027, 0.024487374, 0.0013553652, -0.01805237, 0.03943679, 0.040216073, 0.011135371, -0.054993745, 0.03549363, 0.035439476, 0.068138786, -0.0398116, -0.009493272, -0.0069921943, 0.030358678, -0.038613632, 0.016209394, 0.0044488655, 0.005111907, 0.032767173, -0.022248205, 0.043980308, 0.013299542, -0.05915052, -0.049968775, 0.0027413457, 0.019087747, 0.050426263, 0.020933373, 0.015938044, 0.05620272, -0.06
# ...

# %%
DOCUMENT1 = {
    "title": "Operação do sistema de controle climático",
    "content": "O Googlecar has a climate control system that allows you to adjust the temperature and airflow in the car. To operate the climate control system, use the buttons and knobs located on the center console.  Temperature: The temperature knob controls the temperature inside the car. Turn the knob clockwise to increase the temperature or counterclockwise to decrease the temperature. Airflow: The airflow knob controls the amount of airflow inside the car. Turn the knob clockwise to increase the airflow or counterclockwise to decrease the airflow. Fan speed: The fan speed knob controls the speed of the fan. Turn the knob clockwise to increase the fan speed or counterclockwise to decrease the fan speed. Mode: The mode button allows you to select the desired mode. The available modes are: Auto: The car will automatically adjust the temperature and airflow to maintain a comfortable level. Cool: The car will blow cool air into the car. Heat: The car will blow warm air into the car. Defrost: The car will blow warm air onto the windshield to defrost it."}
DOCUMENT2 = {
    "title": "Touchscreen",
    "content": "Your Googlecar has a large touchscreen display that provides access to a variety of features, including navigation, entertainment, and climate control. To use the touchscreen display, simply touch the desired icon.  For example, you can touch the \"Navigation\" icon to get directions to your destination or touch the \"Music\" icon to play your favorite songs."}
DOCUMENT3 = {
    "title": "Shifting Gears",
    "content": "Your Googlecar has an automatic transmission. To shift gears, simply move the shift lever to the desired position.  Park: This position is used when you are parked. The wheels are locked and the car cannot move. Reverse: This position is used to back up. Neutral: This position is used when you are stopped at a light or in traffic. The car is not in gear and will not move unless you press the gas pedal. Drive: This position is used to drive forward. Low: This position is used for driving in snow or other slippery conditions."}

documents = [DOCUMENT1, DOCUMENT2, DOCUMENT3]

# %%
df = pd.DataFrame(documents)
df.columns = ["Título", "Conteúdo"]
df
# Out:
#                                       Título  \
# 0  Operação do sistema de controle climático
# 1                                Touchscreen
# 2                             Shifting Gears
#
#                                             Conteúdo
# 0  O Googlecar has a climate control system that ...
# 1  Your Googlecar has a large touchscreen display...
# 2  Your Googlecar has an automatic transmission. ...

# %%
model = "models/embedding-001"

# %%
def embed_fn(title, text):
    return genai.embed_content(model=model,
                               content=text,
                               title=title,
                               task_type="RETRIEVAL_DOCUMENT")["embedding"]

# %%
df["embeddings"] = df.apply(lambda row: embed_fn(row["Título"], row["Conteúdo"]), axis=1)
df
# Out:
#                                       Título  \
# 0  Operação do sistema de controle climático
# 1                                Touchscreen
# 2                             Shifting Gears
#
#                                             Conteúdo  \
# 0  O Googlecar has a climate control system that ...
# 1  Your Googlecar has a large touchscreen display...
# 2  Your Googlecar has an automatic transmission. ...
#
#                                           embeddings
# 0  [-0.031663917, -0.016141633, -0.047158018, -0....
# 1  [0.009660736, -0.030662702, -0.017281422, -0.0...
# 2  [-0.04270796, -0.007160868, -0.03242516, -0.02...

# %%
def gerar_e_buscar_consulta(consulta, base, model):
  embedding_da_consulta=genai.embed_content(model=model,
                               content=consulta,
                               task_type="RETRIEVAL_QUERY")["embedding"]
  # produtos escalares
  produtos_escalares = np.dot(np.stack(df['embeddings']), embedding_da_consulta)
  indice = np.argmax(produtos_escalares)
  return df.iloc[indice]["Conteúdo"]

# %%
consulta = "How do you shift gears in the Google car?"

trecho = gerar_e_buscar_consulta(consulta, df, model)

print(trecho)
# Out:
# Your Googlecar has an automatic transmission. To shift gears, simply move the shift lever to the desired position.  Park: This position is used when you are parked. The wheels are locked and the car cannot move. Reverse: This position is used to back up. Neutral: This position is used when you are stopped at a light or in traffic. The car is not in gear and will not move unless you press the gas pedal. Drive: This position is used to drive forward. Low: This position is used for driving in snow or other slippery conditions.

# %%
# Set up the model
generation_config = {
    "temperature": 0.5,
    "candidate_count":1
}

# %%
prompt = f"reescreva esse texto de uma forma mais descontraída, sem adicionar informações sem adicionar informações que não façam parte do texto: {trecho}"

model_2 = genai.GenerativeModel("gemini-1.0-pro")
response = model_2.generate_content(prompt)
print(response.text)
# Out:
# Olha, seu carango do Google tem uma transmissão automática irada! Mudar de marcha é moleza, só meche nessa alavanca aqui:
#
# * **P de Parque:** Usa isso quando for dar uma paradinha. As rodas ficam presas e o carro nem mexe.
# * **R de Ré:** Bota nessa quando quiser dar aquele "voltão".
# * **N de Neutro:** Segura aqui quando estiver parado no farol ou no trânsito. O carro fica desligado, mas só anda se você pisar no acelerador.
# * **D de Dirigiu:** É pra quando você quer dar aquele rolê pra frente.
# * **L de Lei:** Essa é pro rango! Quando rolar neve ou coisa escorregadia, puxa essa marcha.
